# %%
import pandas as pd
import numpy as np
import sympy
from sympy.solvers.inequalities import reduce_rational_inequalities,reduce_inequalities
from itertools import chain
from collections import defaultdict
from IPython.display import display

from sympy.parsing.sympy_parser import parse_expr
from sympy.parsing.sympy_parser import standard_transformations
from sympy.printing.mathml import print_mathml
import math
from IPython.display import display, Markdown, Latex
import os

import seaborn as sns
import matplotlib.pyplot as plt

def make_symbols_positive(sym):
    return sympy.symbols("{}".format(sym),positive =True)

def make_symbols_function(sym):
    return sympy.symbols("{}".format(sym),cl)

def subs_function(target,list_):
    return sympy.simplify(target.subs(list_))

def root_cal(value):
    return value**(1/2)

# %%
class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'

print(color.BOLD + 'Hello World !' + color.END)
# Out:
# Hello World !

# %% [markdown]
# # w_range

# %%
def sol_w_same(df_1,target_):
    w_sol = sympy.solve([df_1["QD"][target_]-df_1["FB"][target_]],w)
    return w_sol

# %%
def sol_w_other(df_1,equa):
    w_sol = sympy.solve(equa,w)
    return w_sol

# %%
def display_solve(df_1,w_sol):
    for row,col in df_1.iterrows():
        print(row)
        try:
            display(col["QD"].subs([(w,w_sol)]).factor())
        except:
            print()
        print()

# %%
def display_solve2(df_1,w_sol):
    for row,col in df_1.iterrows():
        print(row)
        try:
            display(col["QD"].subs([(w,w_sol)]).simplify())
        except:
            print()
        print()

# %%
def display_w_insert(df_,w_1):
    order_ = ["w","epsilon","t","p","q_nd","q_t","q","profit_r","profit_s","profit_all","h1_r_p","h1_s_w","h1_s_e"]
    if w_1 == "WH":
        for ord_ in order_:
            try:
                value_ = df_[1][ord_].factor()
                value_2 = df_[1][ord_].simplify()
                print(color.RED + ord_ + color.END)
                display("factor: ",value_)
                display("simplify: ",value_2)
                print("-"*40)
            except:
                print(color.RED + ord_ + color.END)
                print("-"*40)
    else:
        for ord_ in order_:
            try:
                value_ = df_[1][ord_].subs([(w,w_1)]).factor()
                value_2 = df_[1][ord_].subs([(w,w_1)]).simplify()
                print(color.RED + ord_ + color.END)
                display("factor: ",value_)
                display("simplify: ",value_2)
                print("-"*40)
            except:
                print(color.RED + ord_ + color.END)
                print("-"*40)

# %%
Path_ = r"C:\Users\Samsung\jupyter\Graduation_thesis\result\version_un_4\새 폴더"

# %%
file_list = os.listdir(Path_)
file_list_xlsx = [f for f in file_list if f.endswith(".xlsx")]
#file_FB = [f for f in file_list_xlsx if f.contains("FB")]
#file_WH = [f for f in file_list_xlsx if f.contains("WH")]
#file_QD = [f for f in file_list_xlsx if f.contains("QD")]

# %%
file_name = [li.replace(".xlsx","") for li in file_list_xlsx]
file_name
# Out:
# ['KN_BD_FB',
#  'KN_BD_QD',
#  'KN_BD_WH',
#  'KN_BS_FB',
#  'KN_BS_QD',
#  'KN_BS_WH',
#  'KN_DD_FB',
#  'KN_DD_QD',
#  'KN_DD_WH',
#  'KN_SD_FB',
#  'KN_SD_QD',
#  'KN_SD_WH',
#  'ND_FB',
#  'ND_QD',
#  'ND_WH']

# %%
for fn in file_name:
    path_ = Path_ + "\\{}.xlsx"
    globals() ["{}".format(fn)] = pd.read_excel(path_.format(fn),index_col=0,header=None)
    try:
        globals() ["{}".format(fn)] = globals() ["{}".format(fn)]#.rename(index={"profit_all":"pro_all"})
    except:
        pass

# %%
p,w,c,s,alpha,beta,delta_d,delta_s,epsilon,psi = make_symbols_positive("p,w,c,s,alpha,beta,delta_d,delta_s,epsilon,psi")

# %%
parse_dic = {"p":p,"w":w,"c":c,"s":s
             ,"alpha":alpha,"beta":beta
             ,"delta_d":delta_d,"delta_s":delta_s,"epsilon":epsilon }

# %%
for fn in file_name:
    globals() ["{}".format(fn)][1] = globals() ["{}".format(fn)][1].map(lambda x: parse_expr(x.replace("^","**").replace("lambda","lambda_"),parse_dic))

# %% [markdown]
# # Un cases

# %%
solve_ws = sympy.solve((ND_QD[1]["profit_s"]-ND_WH[1]["profit_s"]).factor(),w)
w_w = solve_ws[1]
w_w
# Out:
# (-alpha + 2*beta*c + sqrt(2)*(alpha - beta*c))/beta

# %%
solve_w = sympy.solve((ND_QD[1]["profit_all"]-ND_FB[1]["profit_all"]).factor(),w)
w_c = solve_w[0]
w_c
# Out:
# alpha/beta

# %%
tar_wh = ND_WH.copy()
tar_qd = ND_QD.copy()

ND_QDW = pd.DataFrame(tar_qd[1].map(lambda x : x.subs([(w,w_w)]).factor())) 
ND_QDC = pd.DataFrame(tar_qd[1].map(lambda x : x.subs([(w,w_c)]).factor()))

# %%
time_ = "KN"
dis_ = "DD"


tar_wh = globals() ["{}_{}_WH".format(time_,dis_)]
tar_qd = globals() ["{}_{}_QD".format(time_,dis_)]

globals() ["{}_{}_QD{}".format(time_,dis_,"W")] = pd.DataFrame(tar_qd[1].map(lambda x : x.subs([(w,w_w)]).factor()))  
globals() ["{}_{}_QD{}".format(time_,dis_,"C")] = pd.DataFrame(tar_qd[1].map(lambda x : x.subs([(w,w_c)]).factor()))  

diss_ = ["DD","SD","BD","BS"]

for dis_ in diss_:
    tar_wh = globals() ["{}_{}_WH".format(time_,dis_)]
    tar_qd = globals() ["{}_{}_QD".format(time_,dis_)]
    globals() ["{}_{}_QD{}".format(time_,dis_,"W")] = pd.DataFrame(tar_qd[1].map(lambda x : x.subs([(w,w_w)]).factor()))  
    globals() ["{}_{}_QD{}".format(time_,dis_,"C")] = pd.DataFrame(tar_qd[1].map(lambda x : x.subs([(w,w_c)]).factor()))

# %%
time_ = "KN"
dis_ = "SD"


tar_wh = globals() ["{}_{}_WH".format(time_,dis_)]
tar_qd = globals() ["{}_{}_QD".format(time_,dis_)]

globals() ["{}_{}_QD{}".format(time_,dis_,"W")] = pd.DataFrame(tar_qd[1].map(lambda x : x.subs([(w,w_w)]).factor()))  
globals() ["{}_{}_QD{}".format(time_,dis_,"C")] = pd.DataFrame(tar_qd[1].map(lambda x : x.subs([(w,w_c)]).factor()))  

diss_ = ["DD","SD","BD","BS"]

for dis_ in diss_:
    tar_wh = globals() ["{}_{}_WH".format(time_,dis_)]
    tar_qd = globals() ["{}_{}_QD".format(time_,dis_)]
    globals() ["{}_{}_QD{}".format(time_,dis_,"W")] = pd.DataFrame(tar_qd[1].map(lambda x : x.subs([(w,w_w)]).factor()))  
    globals() ["{}_{}_QD{}".format(time_,dis_,"C")] = pd.DataFrame(tar_qd[1].map(lambda x : x.subs([(w,w_c)]).factor()))

# %%
time_ = "KN"
dis_ = "BD"


tar_wh = globals() ["{}_{}_WH".format(time_,dis_)]
tar_qd = globals() ["{}_{}_QD".format(time_,dis_)]

globals() ["{}_{}_QD{}".format(time_,dis_,"W")] = pd.DataFrame(tar_qd[1].map(lambda x : x.subs([(w,w_w)]).factor()))  
globals() ["{}_{}_QD{}".format(time_,dis_,"C")] = pd.DataFrame(tar_qd[1].map(lambda x : x.subs([(w,w_c)]).factor()))  

diss_ = ["DD","SD","BD","BS"]

for dis_ in diss_:
    tar_wh = globals() ["{}_{}_WH".format(time_,dis_)]
    tar_qd = globals() ["{}_{}_QD".format(time_,dis_)]
    globals() ["{}_{}_QD{}".format(time_,dis_,"W")] = pd.DataFrame(tar_qd[1].map(lambda x : x.subs([(w,w_w)]).factor()))  
    globals() ["{}_{}_QD{}".format(time_,dis_,"C")] = pd.DataFrame(tar_qd[1].map(lambda x : x.subs([(w,w_c)]).factor()))

# %%
time_ = "KN"
dis_ = "BS"


tar_wh = globals() ["{}_{}_WH".format(time_,dis_)]
tar_qd = globals() ["{}_{}_QD".format(time_,dis_)]

globals() ["{}_{}_QD{}".format(time_,dis_,"W")] = pd.DataFrame(tar_qd[1].map(lambda x : x.subs([(w,w_w)]).factor()))  
globals() ["{}_{}_QD{}".format(time_,dis_,"C")] = pd.DataFrame(tar_qd[1].map(lambda x : x.subs([(w,w_c)]).factor()))  

diss_ = ["DD","SD","BD","BS"]

for dis_ in diss_:
    tar_wh = globals() ["{}_{}_WH".format(time_,dis_)]
    tar_qd = globals() ["{}_{}_QD".format(time_,dis_)]
    globals() ["{}_{}_QD{}".format(time_,dis_,"W")] = pd.DataFrame(tar_qd[1].map(lambda x : x.subs([(w,w_w)]).factor()))  
    globals() ["{}_{}_QD{}".format(time_,dis_,"C")] = pd.DataFrame(tar_qd[1].map(lambda x : x.subs([(w,w_c)]).factor()))

# %%
def hessian_(df_,para_):
    try:
        try:
            a_ = float(df_[1]["h1_r_p"].subs(para_))
            b_ = float(df_[1]["h1_s_w"].subs(para_))
            if a_ and b_ <= 0:
                pass
            else:
                return "STOP",(a_,b_)
        except:
            a_ = float(df_[1]["h1_r_p"].subs(para_))
            b_ = float(df_[1]["h1_s_w"].subs(para_))
            c_ = float(df_[1]["h1_s_e"].subs(para_))
            if a_ and b_ and c_ <= 0:
                pass
            else:
                return "STOP",(a_,b_,c_)
    except:
        pass

# %%
def subs_lambda(y,params):
    try:
        out_ = y.subs(params)
        try:
            out_ = round(float(out_),3)
        except:
            pass
    except:
        out_ = 0
    return out_

# %%
def apply_num(df,para_list):
    return df.apply(lambda x : x.map(lambda y: subs_lambda(y,para_list)))

# %%
file_name_2 = ['KN_BD_FB',
 'KN_BD_QDW',
 'KN_BD_QDC',
 'KN_BD_WH',
 'KN_BS_FB',
 'KN_BS_QDW',
 'KN_BS_QDC',
 'KN_BS_WH',
 'KN_DD_FB',
 'KN_DD_QDW',               
 'KN_DD_QDC',
 'KN_DD_WH',
 'KN_SD_FB',
 'KN_SD_QDW',
 'KN_SD_QDC',
 'KN_SD_WH',
 'ND_FB',
 'ND_QD',
 'ND_WH']

# %%
n_d= 0.4
n_s= 0.3
para_ = [(alpha,1200),(beta,7),(c,50),(delta_d,n_d),(delta_s,n_s),(s,100)]

# %%
for file_ in file_name_2:
    df_test = globals ()["{}".format(file_)]
    print(hessian_(df_test,para_))
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None

# %%
para_ = [(alpha,1200),(beta,7),(c,50),(delta_d,n_d),(delta_s,n_s),(s,100)]
n_d= 0.3
n_s= 0.4

# %%
for file_ in file_name_2:
    df_test = globals ()["{}".format(file_)]
    print(hessian_(df_test,para_))
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None

# %%
s_ = 100
spot_premium = 1.1


df_all = []
for file_ in file_name_2:
    df_1 =  globals ()["{}".format(file_)].rename(columns={1:file_})
    if "DD" in file_:
        n_d = 0.4
        n_s = 0
        para_ = [(alpha,1200),(beta,7),(c,50),(delta_d,n_d),(delta_s,n_s),(s,s_)]

        First_num = apply_num(df_1,para_)
        First_num.loc[len(First_num)] = [s_]
        
    elif "SD" in file_:
        n_d = 0
        n_s = 0.4
        para_ = [(alpha,1200),(beta,7),(c,50),(delta_d,n_d),(delta_s,n_s),(s,s_)]
        price_ = float(df_1[file_]["p"].subs(para_))
        s_1 = price_*spot_premium
        para_ = [(alpha,1200),(beta,7),(c,50),(delta_d,n_d),(delta_s,n_s),(s,s_1)]
        print(hessian_(df_1,para_))
        First_num = apply_num(df_1,para_)
        First_num.loc[len(First_num)] = [s_1]
    elif "BD" in file_:
        #print(file_)
        n_d = 0.4
        n_s = 0.3
        para_ = [(alpha,1200),(beta,7),(c,50),(delta_d,n_d),(delta_s,n_s),(s,s_)]

        First_num = apply_num(df_1,para_)
        First_num.loc[len(First_num)] = [s_]
    elif "BS" in file_:
        #print(file_)
        n_d = 0.3
        n_s = 0.4
        para_ = [(alpha,1200),(beta,7),(c,50),(delta_d,n_d),(delta_s,n_s),(s,s_)]
        price_ = float(df_1[file_]["p"].subs(para_))
        s_1 = price_*spot_premium
        para_ = [(alpha,1200),(beta,7),(c,50),(delta_d,n_d),(delta_s,n_s),(s,s_1)]
        
        
        First_num = apply_num(df_1,para_)
        First_num.loc[len(First_num)] = [s_1]
    else:

        n_d = 0
        n_s = 0    
        para_ = [(alpha,1200),(beta,7),(c,50),(delta_d,n_d),(delta_s,n_s),(s,s_)] 
        
        First_num = apply_num(df_1,para_)
    df_all.append(First_num)
# Out:
# None
# None
# None
# None

# %%
df_con = pd.DataFrame()
for df_2 in df_all:
    df_con = pd.concat([df_con,df_2],axis=1)

# %%
df_con
# Out:
#              KN_BD_FB                                          KN_BD_QDW  \
# p             110.714                                            128.497
# q_d           255.000                                            180.312
# profit_all  15482.143                                              14154
# h1_all_p       -8.400                                                NaN
# 4             100.000                                                NaN
# w                 NaN                                            100.297
# epsilon           NaN                                              0.041
# p_w               NaN  -(10080.0*epsilon - 850*sqrt(2) - 700)/(14*(1 ...
# q_t               NaN                                            180.312
# t                 NaN                                             92.931
# profit_r          NaN                                            6412.91
# profit_s          NaN                                            7741.07
# h1_r_p            NaN                                             -6.959
# h1_s_w            NaN                                             -5.595
# h1_s_e            NaN                                            -397943
# h2_s              NaN                                            -208920
# 14                NaN                                                100
# 11                NaN                                                NaN
# q                 NaN                                                NaN
# T                 NaN                                                NaN
#
#            KN_BD_QDC     KN_BD_WH      KN_BS_FB  \
# p            110.714      141.071    116.122000
# q_d              255        127.5    271.000000
# profit_all   15482.1      11611.6  14987.959000
# h1_all_p         NaN          NaN     -9.800000
# 4                NaN          NaN    125.714286
# w            171.429      110.714           NaN
# epsilon        0.238          NaN           NaN
# p_w          171.429  w/2 + 600/7           NaN
# q_t              255        127.5           NaN
# t            110.714      110.714           NaN
# profit_r           0      3870.54           NaN
# profit_s     15482.1      7741.07           NaN
# h1_r_p             0         -8.4           NaN
# h1_s_w           zoo         -4.2           NaN
# h1_s_e           zoo          NaN           NaN
# h2_s             zoo          NaN           NaN
# 14               100          NaN           NaN
# 11               NaN          100           NaN
# q                NaN          NaN           NaN
# T                NaN          NaN           NaN
#
#                                                     KN_BS_QDW  \
# p                                                     133.697
# q_d                                                   184.887
# profit_all                                            12957.6
# h1_all_p                                                  NaN
# 4                                                         NaN
# w                                                     100.297
# epsilon                                                 0.034
# p_w         -0.102040816326531*(7056.0*epsilon - 510.0*sqr...
# q_t                                                   158.475
# t                                                      94.021
# profit_r                                              5981.47
# profit_s                                              6976.16
# h1_r_p                                                 -8.403
# h1_s_w                                                 -4.548
# h1_s_e                                                -334782
# h2_s                                                  -150652
# 14                                                    145.287
# 11                                                        NaN
# q                                                         NaN
# T                                                         NaN
#
#                                                     KN_BS_QDC  \
# p                                                     117.855
# q_d                                                   262.509
# profit_all                                              14868
# h1_all_p                                                  NaN
# 4                                                         NaN
# w                                                     171.429
# epsilon                                                 0.224
# p_w         -0.102040816326531*(7056.0*epsilon - 1649.9642...
# q_t                                                   225.008
# t                                                     112.502
# profit_r                                              804.555
# profit_s                                              14063.5
# h1_r_p                                                 -0.561
# h1_s_w                                               -581.441
# h1_s_e                                           -1.51598e+08
# h2_s                                              -6.8219e+07
# 14                                                     128.52
# 11                                                        NaN
# q                                                         NaN
# T                                                         NaN
#
#                                           KN_BS_WH   KN_DD_FB  \
# p                                          144.898    110.714
# q_d                                            130    255.000
# profit_all                                 10346.9  15482.143
# h1_all_p                                       NaN     -8.400
# 4                                              NaN    100.000
# w                                          111.905        NaN
# epsilon                                        NaN        NaN
# p_w         0.428571428571429*w + 96.9387755102041        NaN
# q_t                                        111.429        NaN
# t                                          111.905        NaN
# profit_r                                   3448.98        NaN
# profit_s                                   6897.96        NaN
# h1_r_p                                        -9.8        NaN
# h1_s_w                                        -3.6        NaN
# h1_s_e                                         NaN        NaN
# h2_s                                           NaN        NaN
# 14                                             NaN        NaN
# 11                                         157.143        NaN
# q                                              NaN        NaN
# T                                              NaN        NaN
#
#                                                     KN_DD_QDW KN_DD_QDC  \
# p                                                     128.497   110.714
# q_d                                                   180.312       255
# profit_all                                              14154   15482.1
# h1_all_p                                                  NaN       NaN
# 4                                                         NaN       NaN
# w                                                     100.297   171.429
# epsilon                                                 0.041     0.238
# p_w         -(10080.0*epsilon - 850*sqrt(2) - 700)/(14*(1 ...   171.429
# q_t                                                   180.312       255
# t                                                      92.931   110.714
# profit_r                                              6412.91         0
# profit_s                                              7741.07   15482.1
# h1_r_p                                                 -6.959         0
# h1_s_w                                                 -5.595       zoo
# h1_s_e                                                -397943       zoo
# h2_s                                                  -208920       zoo
# 14                                                        100       100
# 11                                                        NaN       NaN
# q                                                         NaN       NaN
# T                                                         NaN       NaN
#
#                KN_DD_WH       KN_SD_FB  \
# p               141.071        127.271
# q_d               127.5  720.0 - 4.2*p
# profit_all      11611.6          13649
# h1_all_p            NaN            -14
# 4                   NaN        132.786
# w               110.714            NaN
# epsilon             NaN            NaN
# p_w         w/2 + 600/7            NaN
# q_t               127.5            NaN
# t               110.714            NaN
# profit_r        3870.54            NaN
# profit_s        7741.07            NaN
# h1_r_p             -8.4            NaN
# h1_s_w             -4.2            NaN
# h1_s_e              NaN            NaN
# h2_s                NaN            NaN
# 14                  NaN            NaN
# 11                  100            NaN
# q                   NaN            NaN
# T                   NaN            NaN
#
#                                                     KN_SD_QDW  \
# p                                                     143.765
# q_d                                                   193.647
# profit_all                                            10227.1
# h1_all_p                                                  NaN
# 4                                                         NaN
# w                                                     100.297
# epsilon                                                 0.022
# p_w         (-10080.0*epsilon + 510.0*sqrt(2) + 1326.66261...
# q_t                                                   116.188
# t                                                      96.106
# profit_r                                              4870.05
# profit_s                                                 5357
# h1_r_p                                                -12.727
# h1_s_w                                                 -2.911
# h1_s_e                                                -228679
# h2_s                                                 -72033.9
# 14                                                     152.38
# 11                                                        NaN
# q                                                         NaN
# T                                                         NaN
#
#                                                     KN_SD_QDC        KN_SD_WH  \
# p                                                     131.921         152.139
# q_d                                                    276.55         135.025
# profit_all                                            12628.5         7813.61
# h1_all_p                                                  NaN             NaN
# 4                                                         NaN             NaN
# w                                                     171.429         114.298
# epsilon                                                 0.201             NaN
# p_w         (2313.8 - 10080.0*epsilon)/(14*(1 - 4.2*epsilon))  0.3*w + 117.85
# q_t                                                    165.93          81.015
# t                                                     115.845         114.298
# profit_r                                              1702.76         2604.54
# profit_s                                              10925.7         5209.07
# h1_r_p                                                 -2.182             -14
# h1_s_w                                                 -59.96           -2.52
# h1_s_e                                           -1.58698e+07             NaN
# h2_s                                             -4.99898e+06             NaN
# 14                                                    140.643             NaN
# 11                                                        NaN         160.679
# q                                                         NaN             NaN
# T                                                         NaN             NaN
#
#                 ND_FB                                              ND_QD  \
# p             110.714                                       1075/7 - w/4
# q_d               NaN                                                NaN
# profit_all  25803.571                       -7*w**2/16 + 150*w + 90625/7
# h1_all_p      -14.000                                                NaN
# 4                 NaN                                                NaN
# w                 NaN                                                  w
# epsilon           NaN                      (21*w - 1900)/(7*(7*w + 500))
# p_w               NaN    (-16800*epsilon + 7*w + 1200)/(14 - 98*epsilon)
# q_t               NaN                                                NaN
# t                 NaN                                                NaN
# profit_r          NaN                      (1200 - 7*w)*(7*w/4 + 125)/14
# profit_s          NaN                       (7*w/4 + 125)*(7*w + 500)/28
# h1_r_p            NaN                       -28*(1200 - 7*w)/(7*w + 500)
# h1_s_w            NaN  -7*(-49*w**2 + 16800*w + 1450000)/(8*(1200 - 7...
# h1_s_e            NaN             -7*(7*w + 500)**4/(32*(1200 - 7*w)**2)
# h2_s              NaN           -49*(7*w + 500)**4/(256*(1200 - 7*w)**2)
# 14                NaN                                                NaN
# 11                NaN                                                NaN
# q             425.000                                        7*w/4 + 125
# T                 NaN                                        w/4 + 475/7
#
#                   ND_WH
# p               141.071
# q_d                 NaN
# profit_all      19352.7
# h1_all_p            NaN
# 4                   NaN
# w               110.714
# epsilon             NaN
# p_w         w/2 + 600/7
# q_t                 NaN
# t                   NaN
# profit_r        6450.89
# profit_s        12901.8
# h1_r_p              -14
# h1_s_w               -7
# h1_s_e              NaN
# h2_s                NaN
# 14                  NaN
# 11                  NaN
# q                 212.5
# T               110.714

# %%
df_con.to_excel(r"C:\Users\Samsung\jupyter\Graduation_thesis\result\graph_\kn_1.xlsx")

# %%
KN_BD_QDC[1]["q_t"]
# Out:
# (-alpha + beta*c)*(delta_d - 1)/2

# %%
KN_BD_QDC[1]["q_d"]
# Out:
# (-alpha + beta*c)*(delta_d - 1)/2
